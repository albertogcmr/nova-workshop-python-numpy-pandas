# %% [markdown]
# ![](data:image/jpeg;base64,...)

# %%
import pandas as pd

# Importamos el famoso CSV de pokemon. 

df = pd.read_csv('Pokemon_clean.csv', index_col=0)
df.head(10)
# Out:
#                Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# #
# 1         Bulbasaur  Grass  Poison    318  45      49       49       65
# 2           Ivysaur  Grass  Poison    405  60      62       63       80
# 3          Venusaur  Grass  Poison    525  80      82       83      100
# 3     Mega Venusaur  Grass  Poison    625  80     100      123      122
# 4        Charmander   Fire     NaN    309  39      52       43       60
# 5        Charmeleon   Fire     NaN    405  58      64       58       80
# 6         Charizard   Fire  Flying    534  78      84       78      109
# 6  Mega Charizard X   Fire  Dragon    634  78     130      111      130
# 6  Mega Charizard Y   Fire  Flying    634  78     104       78      159
# 7          Squirtle  Water     NaN    314  44      48       65       50
#
#    Sp. Def  Speed  Generation  Legendary
# #
# 1       65     45           1      False
# 2       80     60           1      False
# 3      100     80           1      False
# ...

# %%
# cuantos pokemon tenemos en nuestra base de datos?

# %%
# cuales son las estadísticas de Snorlax?

# %%
# qué pokemon tiene más Attack que ningún otro?

# %%
# Cuanto es ese Attack

# %%
# ¿quien tiene más HP los legendario o los no legendarios?

# %%
# Cuenta los de "Type 1" fuego

# %%
# cuantos pokemon hay de cada generacion

# %%
# Siéntete libre de realizar alguna visualización sobre este dataset
